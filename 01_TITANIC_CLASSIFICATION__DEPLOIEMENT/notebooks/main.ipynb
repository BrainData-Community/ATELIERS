# %% [markdown]
# # Titanic classification (A à Z)
#
# **Objectif:** Mettre en place un modèle de machine capable de prédire si une personne aurait survécu au titanic en fonction des données du jeu de données.
#
# * 80% de précision et un F1-Score à 50% (prédire qu'une personne va survivre est plus important pour nous)
#
# **Auteur:** Elishama Kadjo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Installation des packages nécessaires

# %%
# %%capture
# %pip install pandas matplotlib numpy scikit-learn statsmodels seaborn fastapi flask

# %% [markdown]
# ## Importation des packages nécessaires

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# ## Chargement et aperçu des données

# %%
pd.set_option("display.max_columns", 111)
pd.set_option("display.max_rows", 10000)

# %%
warnings.filterwarnings("ignore")

# %%
path = "../data/titanic.csv"
# lecture du jeu de données
data = pd.read_csv(path)

# %%
df = data.copy(deep=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## EDA (Exploratory Data Analysis)
#
# **Objectif:** Comprendre au maximum les données dont on dispose pour définir une startégie de modélisation

# %% [markdown]
# ### Analyse de la forme du jeu de données:
# * Identification de la target: `Survived`
# * Nombre de lignes et de colonnes: (891, 12)
# * Types de variables: quantitatives: 7, qualitatives: 5
# * Identification des valeurs manquantes:

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes.value_counts()
# Out:
# int64      5
# str        5
# float64    2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df)

# %% [markdown]
# ### Analyse du fond
#
# * **Visualisation de la target:**
#
# * **Signification des variables**
#
# * **Relation Variables/Target**

# %% [markdown]
# #### Visualisation initiale - élimination des colonnes inutiles

# %% [markdown]
# #### Analyse de la target

# %% [markdown]
# #### Analyse univariée
#
# **Objectif:** Comprendre la distribution de nos différentes variables afin de pouvoir comprendre comment nos données sont organisées
#
# * A quoi ressmeble notre individu moyen ?
# * Es ce que toutes les observation sont concentré autour de la moyenne ?
# * A ressemble notre médiane ?

# %% [markdown]
# #### Analyse Bivariée
#
# **Objectif:** Analyser les relations qu'il y'a entre les variables explicatives et la variables à expliquer _(a survecu ?)_

# %% [markdown]
# #### Analyse détaillée
#
# * Relation entre les variables ? (eviter le risque de multicolinéarité par exemple ...)
#
# * Analyse des valeurs manquantes (NaN)
#
# **Hypothèses:**
#
# *
# *

# %% [markdown]
# ### Préprocessing
#
# **Objectif:** Préparer les données pour qu'elles soient dans un format propice au machien learning.
#
# * Création du Train Set / Test Set
# * Elimination des NaN
# * Encodage
# * Suppression des outliers néfastes au modèle (après first ML modèle + Analyse)
# * Feature Selection
# * Feature Engineering
# * Feature Scaling

# %% [markdown]
# ### Modélisation
#
# **Objectif:** Développer un modèle de machine learning qui réponde à l'objectif final.
